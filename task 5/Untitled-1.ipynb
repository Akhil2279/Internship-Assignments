# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("sales_data.csv")

# Show first few rows
print(" Sales Data Preview:")
print(df.head())

# Total Sales by Category
category_sales = df.groupby("Category")["Sales"].sum()
print("\n Total Sales by Category:")
print(category_sales)

# Total Quantity Sold by Product
product_quantity = df.groupby("Product")["Quantity"].sum()
print("\n Quantity Sold by Product:")
print(product_quantity)

# Daily Sales Trend
daily_sales = df.groupby("Date")["Sales"].sum()
print("\n Daily Sales Trend:")
print(daily_sales)

# --- Plot Charts ---
# Sales by Category
category_sales.plot(kind="bar", title="Total Sales by Category")
plt.ylabel("Sales")
plt.show()

# Quantity by Product
product_quantity.plot(kind="bar", title="Quantity Sold by Product")
plt.ylabel("Quantity")
plt.show()

# Daily Sales Trend
daily_sales.plot(kind="line", marker="o", title="Daily Sales Trend")
plt.ylabel("Sales")
plt.show()
# Out:
# 📊 Sales Data Preview:
#          Date     Product     Category  Sales  Quantity
# 0  2025-01-01      Mobile  Electronics  20000         5
# 1  2025-01-01      Laptop  Electronics  50000         2
# 2  2025-01-02  Headphones  Electronics   5000        10
# 3  2025-01-02       Shoes      Fashion   3000         4
# 4  2025-01-03     T-shirt      Fashion   1500         6
#
# 💰 Total Sales by Category:
# Category
# Electronics    175000
# Fashion          8500
# Name: Sales, dtype: int64
#
# 📦 Quantity Sold by Product:
# Product
# Headphones    10
# Laptop         3
# Mobile         9
# Shoes          4
# T-shirt        6
# Tablet         3
# Watch          5
# Name: Quantity, dtype: int64
#
# 📅 Daily Sales Trend:
# Date
# 2025-01-01    70000
# 2025-01-02     8000
# 2025-01-03    16500
# 2025-01-04    64000
# 2025-01-05    25000
# Name: Sales, dtype: int64

# %%
import csv

# Define the file path
file_path = r"C:\Users\akhil\Documents\sales_data.csv"

# Data to write (list of lists)
data = [
    ["Date", "Product", "Category", "Sales", "Quantity"],
    ["2025-01-01", "Mobile", "Electronics", 20000, 5],
    ["2025-01-01", "Laptop", "Electronics", 50000, 2],
    ["2025-01-02", "Headphones", "Electronics", 5000, 10],
    ["2025-01-02", "Shoes", "Fashion", 3000, 4],
    ["2025-01-03", "T-shirt", "Fashion", 1500, 6],
    ["2025-01-03", "Tablet", "Electronics", 15000, 3],
    ["2025-01-04", "Watch", "Fashion", 4000, 5],
    ["2025-01-04", "Laptop", "Electronics", 60000, 1],
    ["2025-01-05", "Mobile", "Electronics", 25000, 4],
]

# Write data to CSV
with open(file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)

print("✅ CSV file created successfully at:", file_path)
# Out:
# ✅ CSV file created successfully at: C:\Users\akhil\Documents\sales_data.csv
